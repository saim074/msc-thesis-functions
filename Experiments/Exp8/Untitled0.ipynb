# %%
# !wget -O mat.py https://raw.githubusercontent.com/saim074/msc-thesis/main/mat.py?token=GHSAT0AAAAAACL4DFMNIS53RBGFNZFL7BPKZMFVAZA
# !wget -O optimize.py https://raw.githubusercontent.com/saim074/msc-thesis/main/optimize.py?token=GHSAT0AAAAAACL4DFMN6N3GGHZPHTHF3ATAZMFVBSQ
# !wget -O synthetic_data.py https://raw.githubusercontent.com/saim074/msc-thesis/main/optimize.py?token=GHSAT0AAAAAACL4DFMN6N3GGHZPHTHF3ATAZMFVBSQ

from mat import *
from optimize import *
# Out:
# --2023-12-22 15:15:31--  https://raw.githubusercontent.com/saim074/msc-thesis/main/mat.py?token=GHSAT0AAAAAACL4DFMNIS53RBGFNZFL7BPKZMFVAZA
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 88537 (86K) [text/plain]
# Saving to: ‘mat.py’
#
# mat.py              100%[===================>]  86.46K  --.-KB/s    in 0.003s
#
# 2023-12-22 15:15:31 (28.1 MB/s) - ‘mat.py’ saved [88537/88537]
